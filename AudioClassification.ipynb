# %% [markdown]
# # 1. Import and Install Dependencies

# %% [markdown]
# ## 1.1 Install Dependencies

# %%
# !pip install tensorflow==2.16.1 matplotlib
# Out:
# Collecting tensorflow==2.16.1
#   Using cached tensorflow-2.16.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib in c:\users\ghaid\anaconda3\lib\site-packages (3.8.4)
# Collecting tensorflow-intel==2.16.1 (from tensorflow==2.16.1)
#   Downloading tensorflow_intel-2.16.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.65.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow-intel==2.16.1->tensorflow==2.16.1)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.0.0 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.4.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow==2.16.1) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghaid\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghaid\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghaid\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ghaid\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\ghaid\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghaid\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ghaid\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.43.0)
# Requirement already satisfied: rich in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (13.7.0)
# Requirement already satisfied: namex in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.0.7)
# Requirement already satisfied: optree in c:\users\ghaid\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ghaid\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ghaid\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow==2.16.1) (0.1.2)
# Downloading tensorflow-2.16.1-cp312-cp312-win_amd64.whl (2.1 kB)
# Downloading tensorflow_intel-2.16.1-cp312-cp312-win_amd64.whl (377.1 MB)
#    ---------------------------------------- 0.0/377.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/377.1 MB 640.0 kB/s eta 0:09:50
#    ---------------------------------------- 0.0/377.1 MB 487.6 kB/s eta 0:12:54
#    ---------------------------------------- 0.1/377.1 MB 657.6 kB/s eta 0:09:34
#    ---------------------------------------- 0.2/377.1 MB 984.6 kB/s eta 0:06:23
#    ---------------------------------------- 0.2/377.1 MB 1.1 MB/s eta 0:05:30
#    ---------------------------------------- 0.3/377.1 MB 1.2 MB/s eta 0:05:18
#    ---------------------------------------- 0.4/377.1 MB 1.4 MB/s eta 0:04:34
#    ---------------------------------------- 0.6/377.1 MB 1.8 MB/s eta 0:03:35
#    ---------------------------------------- 0.8/377.1 MB 2.1 MB/s eta 0:02:56
#    ---------------------------------------- 1.3/377.1 MB 2.9 MB/s eta 0:02:12
#    ---------------------------------------- 1.5/377.1 MB 3.2 MB/s eta 0:01:58
#    ---------------------------------------- 1.7/377.1 MB 3.3 MB/s eta 0:01:54
#    ---------------------------------------- 2.1/377.1 MB 3.7 MB/s eta 0:01:42
#    ---------------------------------------- 2.5/377.1 MB 4.0 MB/s eta 0:01:33
#    ---------------------------------------- 2.5/377.1 MB 3.8 MB/s eta 0:01:40
#    ---------------------------------------- 2.8/377.1 MB 3.9 MB/s eta 0:01:36
#    ---------------------------------------- 2.8/377.1 MB 3.9 MB/s eta 0:01:36
#    ---------------------------------------- 3.6/377.1 MB 4.4 MB/s eta 0:01:26
#    ---------------------------------------- 3.6/377.1 MB 4.2 MB/s eta 0:01:29
#    ---------------------------------------- 3.9/377.1 MB 4.3 MB/s eta 0:01:27
#    ---------------------------------------- 4.4/377.1 MB 4.6 MB/s eta 0:01:22
#    ---------------------------------------- 4.6/377.1 MB 4.7 MB/s eta 0:01:20
#     --------------------------------------- 4.8/377.1 MB 4.5 MB/s eta 0:01:23
#     --------------------------------------- 5.2/377.1 MB 4.8 MB/s eta 0:01:19
#     --------------------------------------- 5.5/377.1 MB 4.9 MB/s eta 0:01:17
#     --------------------------------------- 5.8/377.1 MB 5.0 MB/s eta 0:01:15
#     --------------------------------------- 5.9/377.1 MB 4.8 MB/s eta 0:01:18
#    -------------------------------------- - 364.4/377.1 MB 7.0 MB/s eta 0:00:02
#    -------------------------------------- - 364.9/377.1 MB 7.0 MB/s eta 0:00:02
#    -------------------------------------- - 365.1/377.1 MB 7.0 MB/s eta 0:00:02
#    -------------------------------------- - 365.1/377.1 MB 7.0 MB/s eta 0:00:02
#    -------------------------------------- - 365.2/377.1 MB 6.5 MB/s eta 0:00:02
#    -------------------------------------- - 365.7/377.1 MB 6.8 MB/s eta 0:00:02
#    -------------------------------------- - 366.2/377.1 MB 6.8 MB/s eta 0:00:02
#    -------------------------------------- - 366.4/377.1 MB 7.1 MB/s eta 0:00:02
#    -------------------------------------- - 366.4/377.1 MB 7.1 MB/s eta 0:00:02
#    -------------------------------------- - 366.6/377.1 MB 6.7 MB/s eta 0:00:02
#    -------------------------------------- - 367.1/377.1 MB 6.5 MB/s eta 0:00:02
#    ---------------------------------------  367.7/377.1 MB 6.6 MB/s eta 0:00:02
#    ---------------------------------------  368.0/377.1 MB 7.2 MB/s eta 0:00:02
#    ---------------------------------------  368.0/377.1 MB 7.2 MB/s eta 0:00:02
#    ---------------------------------------  368.3/377.1 MB 6.8 MB/s eta 0:00:02
#    ---------------------------------------  368.7/377.1 MB 6.5 MB/s eta 0:00:02
#    ---------------------------------------  369.2/377.1 MB 6.7 MB/s eta 0:00:02
#    ---------------------------------------  369.7/377.1 MB 7.0 MB/s eta 0:00:02
#    ---------------------------------------  370.0/377.1 MB 6.9 MB/s eta 0:00:02
#    ---------------------------------------  370.5/377.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  370.9/377.1 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  371.2/377.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  371.2/377.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  372.3/377.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  372.3/377.1 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  372.6/377.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  373.1/377.1 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------  373.4/377.1 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  374.0/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  374.4/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  374.5/377.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  375.1/377.1 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  375.5/377.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  375.5/377.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  375.7/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  376.2/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  376.6/377.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  376.6/377.1 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------  376.8/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.1/377.1 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 377.1/377.1 MB 5.6 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.5 MB 14.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.8/5.5 MB 10.0 MB/s eta 0:00:01
#    --------- ------------------------------ 1.3/5.5 MB 10.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.6/5.5 MB 10.0 MB/s eta 0:00:01
#    ------------ --------------------------- 1.7/5.5 MB 7.7 MB/s eta 0:00:01
#    --------------- ------------------------ 2.1/5.5 MB 7.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.5/5.5 MB 7.9 MB/s eta 0:00:01
#    --------------------- ------------------ 3.0/5.5 MB 8.3 MB/s eta 0:00:01
#    ------------------------ --------------- 3.4/5.5 MB 8.3 MB/s eta 0:00:01
#    --------------------------- ------------ 3.8/5.5 MB 8.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.0/5.5 MB 8.2 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 8.5 MB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 8.5 MB/s eta 0:00:01
#    -------------------------------------- - 5.3/5.5 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.17.0
#     Uninstalling tensorflow-intel-2.17.0:
#       Successfully uninstalled tensorflow-intel-2.17.0
#   Rolling back uninstall of tensorflow-intel
#   Moving to c:\users\ghaid\anaconda3\lib\site-packages\tensorflow\
#    from C:\Users\ghaid\anaconda3\Lib\site-packages\~ensorflow
#   Moving to c:\users\ghaid\anaconda3\lib\site-packages\tensorflow_intel-2.17.0.dist-info\
#    from C:\Users\ghaid\anaconda3\Lib\site-packages\~ensorflow_intel-2.17.0.dist-info
#   Moving to c:\users\ghaid\anaconda3\scripts\import_pb_to_tensorboard.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\import_pb_to_tensorboard.exe
#   Moving to c:\users\ghaid\anaconda3\scripts\saved_model_cli.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\saved_model_cli.exe
#   Moving to c:\users\ghaid\anaconda3\scripts\tensorboard.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\tensorboard.exe
#   Moving to c:\users\ghaid\anaconda3\scripts\tf_upgrade_v2.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\tf_upgrade_v2.exe
#   Moving to c:\users\ghaid\anaconda3\scripts\tflite_convert.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\tflite_convert.exe
#   Moving to c:\users\ghaid\anaconda3\scripts\toco.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\toco.exe
#   Moving to c:\users\ghaid\anaconda3\scripts\toco_from_protos.exe
#    from C:\Users\ghaid\AppData\Local\Temp\pip-uninstall-ob99e0pt\toco_from_protos.exe
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device

# %%
# !pip install tensorflow-io
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-io (from versions: none)
# ERROR: No matching distribution found for tensorflow-io

# %% [markdown]
# ## 1.2 Load Dependencies

# %%
import os
from matplotlib import pyplot as plt
import tensorflow as tf 
import tensorflow_io as tfio

# %% [markdown]
# # 2. Build Data Loading Function

# %% [markdown]
# ## 2.1 Define Paths to Files

# %%
CAPUCHIN_FILE = os.path.join('data', 'Parsed_Capuchinbird_Clips', 'XC3776-3.wav')
NOT_CAPUCHIN_FILE = os.path.join('data', 'Parsed_Not_Capuchinbird_Clips', 'afternoon-birds-song-in-forest-0.wav')

# %% [markdown]
# ## 2.2 Build Dataloading Function

# %%
def load_wav_16k_mono(filename):
    # Load encoded wav file
    file_contents = tf.io.read_file(filename)
    # Decode wav (tensors by channels) 
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    # Removes trailing axis
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    # Goes from 44100Hz to 16000hz - amplitude of the audio signal
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %% [markdown]
# ## 2.3 Plot Wave

# %%
wave = load_wav_16k_mono(CAPUCHIN_FILE)
nwave = load_wav_16k_mono(NOT_CAPUCHIN_FILE)

# %%
plt.plot(wave)
plt.plot(nwave)
plt.show()

# %% [markdown]
# # 3. Create Tensorflow Dataset

# %% [markdown]
# ## 3.1 Define Paths to Positive and Negative Data

# %%
POS = os.path.join('data', 'Parsed_Capuchinbird_Clips')
NEG = os.path.join('data', 'Parsed_Not_Capuchinbird_Clips')

# %% [markdown]
# ## 3.2 Create Tensorflow Datasets

# %%
pos = tf.data.Dataset.list_files(POS+'\*.wav')
neg = tf.data.Dataset.list_files(NEG+'\*.wav')

# %% [markdown]
# ## 3.3 Add labels and Combine Positive and Negative Samples

# %%
positives = tf.data.Dataset.zip((pos, tf.data.Dataset.from_tensor_slices(tf.ones(len(pos)))))
negatives = tf.data.Dataset.zip((neg, tf.data.Dataset.from_tensor_slices(tf.zeros(len(neg)))))
data = positives.concatenate(negatives)

# %% [markdown]
# # 4. Determine Average Length of a Capuchin Call

# %% [markdown]
# ## 4.1 Calculate Wave Cycle Length

# %%
lengths = []
for file in os.listdir(os.path.join('data', 'Parsed_Capuchinbird_Clips')):
    tensor_wave = load_wav_16k_mono(os.path.join('data', 'Parsed_Capuchinbird_Clips', file))
    lengths.append(len(tensor_wave))

# %% [markdown]
# ## 4.2 Calculate Mean, Min and Max

# %%
tf.math.reduce_mean(lengths)

# %%
tf.math.reduce_min(lengths)

# %%
tf.math.reduce_max(lengths)

# %% [markdown]
# # 5. Build Preprocessing Function to Convert to Spectrogram

# %% [markdown]
# ## 5.1 Build Preprocessing Function

# %%
def preprocess(file_path, label): 
    wav = load_wav_16k_mono(file_path)
    wav = wav[:48000]
    zero_padding = tf.zeros([48000] - tf.shape(wav), dtype=tf.float32)
    wav = tf.concat([zero_padding, wav],0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram, label

# %% [markdown]
# ## 5.2 Test Out the Function and Viz the Spectrogram

# %%
filepath, label = positives.shuffle(buffer_size=10000).as_numpy_iterator().next()

# %%
spectrogram, label = preprocess(filepath, label)

# %%
plt.figure(figsize=(30,20))
plt.imshow(tf.transpose(spectrogram)[0])
plt.show()

# %% [markdown]
# # 6. Create Training and Testing Partitions

# %% [markdown]
# ## 6.1 Create a Tensorflow Data Pipeline

# %%
data = data.map(preprocess)
data = data.cache()
data = data.shuffle(buffer_size=1000)
data = data.batch(16)
data = data.prefetch(8)

# %% [markdown]
# ## 6.2 Split into Training and Testing Partitions

# %%
train = data.take(36)
test = data.skip(36).take(15)

# %% [markdown]
# ## 6.3 Test One Batch

# %%
samples, labels = train.as_numpy_iterator().next()

# %%
samples.shape

# %% [markdown]
# # 7. Build Deep Learning Model

# %% [markdown]
# ## 7.1 Load Tensorflow Dependencies

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten

# %% [markdown]
# ## 7.2 Build Sequential Model, Compile and View Summary

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), activation='relu', input_shape=(1491, 257,1)))
model.add(Conv2D(16, (3,3), activation='relu'))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('Adam', loss='BinaryCrossentropy', metrics=[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# %%
model.summary()

# %% [markdown]
# ## 7.3 Fit Model, View Loss and KPI Plots

# %%
hist = model.fit(train, epochs=4, validation_data=test)

# %%
plt.title('Loss')
plt.plot(hist.history['loss'], 'r')
plt.plot(hist.history['val_loss'], 'b')
plt.show()

# %%
plt.title('Precision')
plt.plot(hist.history['precision'], 'r')
plt.plot(hist.history['val_precision'], 'b')
plt.show()

# %%
plt.title('Recall')
plt.plot(hist.history['recall'], 'r')
plt.plot(hist.history['val_recall'], 'b')
plt.show()

# %% [markdown]
# # 8. Make a Prediction on a Single Clip

# %% [markdown]
# ## 8.1 Get One Batch and Make a Prediction

# %%
X_test, y_test = test.as_numpy_iterator().next()

# %%
yhat = model.predict(X_test)

# %% [markdown]
# ## 8.2 Convert Logits to Classes

# %%
yhat = [1 if prediction > 0.5 else 0 for prediction in yhat]

# %% [markdown]
# # 9. Build Forest Parsing Functions

# %% [markdown]
# ## 9.1 Load up MP3s

# %%
def load_mp3_16k_mono(filename):
    """ Load a WAV file, convert it to a float tensor, resample to 16 kHz single-channel audio. """
    res = tfio.audio.AudioIOTensor(filename)
    # Convert to tensor and combine channels 
    tensor = res.to_tensor()
    tensor = tf.math.reduce_sum(tensor, axis=1) / 2 
    # Extract sample rate and cast
    sample_rate = res.rate
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    # Resample to 16 kHz
    wav = tfio.audio.resample(tensor, rate_in=sample_rate, rate_out=16000)
    return wav

# %%
mp3 = os.path.join('data', 'Forest Recordings', 'recording_00.mp3')

# %%
wav = load_mp3_16k_mono(mp3)

# %%
audio_slices = tf.keras.utils.timeseries_dataset_from_array(wav, wav, sequence_length=48000, sequence_stride=48000, batch_size=1)

# %%
samples, index = audio_slices.as_numpy_iterator().next()

# %% [markdown]
# ## 9.2 Build Function to Convert Clips into Windowed Spectrograms

# %%
def preprocess_mp3(sample, index):
    sample = sample[0]
    zero_padding = tf.zeros([48000] - tf.shape(sample), dtype=tf.float32)
    wav = tf.concat([zero_padding, sample],0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram

# %% [markdown]
# ## 9.3 Convert Longer Clips into Windows and Make Predictions

# %%
audio_slices = tf.keras.utils.timeseries_dataset_from_array(wav, wav, sequence_length=16000, sequence_stride=16000, batch_size=1)
audio_slices = audio_slices.map(preprocess_mp3)
audio_slices = audio_slices.batch(64)

# %%
yhat = model.predict(audio_slices)
yhat = [1 if prediction > 0.5 else 0 for prediction in yhat]

# %% [markdown]
# ## 9.4 Group Consecutive Detections

# %%
from itertools import groupby

# %%
yhat = [key for key, group in groupby(yhat)]
calls = tf.math.reduce_sum(yhat).numpy()

# %%
calls

# %% [markdown]
# # 10. Make Predictions

# %% [markdown]
# ## 10.1 Loop over all recordings and make predictions

# %%
results = {}
for file in os.listdir(os.path.join('data', 'Forest Recordings')):
    FILEPATH = os.path.join('data','Forest Recordings', file)
    
    wav = load_mp3_16k_mono(FILEPATH)
    audio_slices = tf.keras.utils.timeseries_dataset_from_array(wav, wav, sequence_length=48000, sequence_stride=48000, batch_size=1)
    audio_slices = audio_slices.map(preprocess_mp3)
    audio_slices = audio_slices.batch(64)
    
    yhat = model.predict(audio_slices)
    
    results[file] = yhat

# %%
results

# %% [markdown]
# ## 10.2 Convert Predictions into Classes

# %%
class_preds = {}
for file, logits in results.items():
    class_preds[file] = [1 if prediction > 0.99 else 0 for prediction in logits]
class_preds

# %% [markdown]
# ## 10.3 Group Consecutive Detections

# %%
postprocessed = {}
for file, scores in class_preds.items():
    postprocessed[file] = tf.math.reduce_sum([key for key, group in groupby(scores)]).numpy()
postprocessed

# %% [markdown]
# # 11. Export Results

# %%
import csv

# %%
with open('results.csv', 'w', newline='') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(['recording', 'capuchin_calls'])
    for key, value in postprocessed.items():
        writer.writerow([key, value])
